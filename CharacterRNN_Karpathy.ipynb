# %% [markdown]
# <a href="https://colab.research.google.com/github/drwitt/NLP_IDS_690-03/blob/master/CharacterRNN_Karpathy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
'''
Created on Sep 27, 2016
some changes: wz
'''
"""
Source: Minimal character-level Vanilla RNN model. Written by Andrej Karpathy (@karpathy)
BSD License
"""

inputTxt ="/content/gdrive/My Drive/doyleBask.txt"

import numpy as np


quit()
# data I/O
data = open(inputTxt, 'r').read() # should be simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print ('data has %d characters, %d unique.' % (data_size, vocab_size))
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }

# hyperparameters
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1

# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

def lossFun(inputs, targets, hprev):
  """
  inputs,targets are both list of integers.
  hprev is Hx1 array of initial hidden state
  returns the loss, gradients on model parameters, and last hidden state
  """
  xs, hs, ys, ps = {}, {}, {}, {}
  hs[-1] = np.copy(hprev)
  loss = 0
  # forward pass
  for t in range(len(inputs)):
    xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
    xs[t][inputs[t]] = 1
    hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
    ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
    ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
    loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
  # backward pass: compute gradients going backwards
  dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
  dbh, dby = np.zeros_like(bh), np.zeros_like(by)
  dhnext = np.zeros_like(hs[0])
  for t in reversed(range(len(inputs))):
    dy = np.copy(ps[t])
    dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
    dWhy += np.dot(dy, hs[t].T)
    dby += dy
    dh = np.dot(Why.T, dy) + dhnext # backprop into h
    dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
    dbh += dhraw
    dWxh += np.dot(dhraw, xs[t].T)
    dWhh += np.dot(dhraw, hs[t-1].T)
    dhnext = np.dot(Whh.T, dhraw)
  for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
    np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
  return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

def sample(h, seed_ix, n):
  """ 
  sample a sequence of integers from the model 
  h is memory state, seed_ix is seed letter for first time step
  """
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1
  ixes = []
  for t in range(n):
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    y = np.dot(Why, h) + by
    p = np.exp(y) / np.sum(np.exp(y))
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    ixes.append(ix)
  return ixes

n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0
while True:
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p+seq_length+1 >= len(data) or n == 0: 
    hprev = np.zeros((hidden_size,1)) # reset RNN memory
    p = 0 # go from start of data
  inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
  targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

  # sample from the model now and then
  if n % 100 == 0:
    sample_ix = sample(hprev, inputs[0], 200)
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)
    print( '----\n %s \n----' % (txt, ))

  # forward seq_length characters through the net and fetch gradient
  loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  if n % 100 == 0: print ('iter %d, loss: %f' % (n, smooth_loss)) # print progress
  
  # perform parameter update with Adagrad
  for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                [dWxh, dWhh, dWhy, dbh, dby], 
                                [mWxh, mWhh, mWhy, mbh, mby]):
    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  p += seq_length # move data pointer
  n += 1 # iteration counter
# Out:
# data has 373567 characters, 94 unique.
# ----
#  O1)
# k;(N#kV—D.ye!r4c@n;uuzTFUt42æKE$EXOpwo“æHahd	bUw“klTt:I
# U]CE9”0fdL*	':lso”QuhJBzœ@0R?m-aj#vpVqWHK”jYax-;HOtnXd?(Gmep7k’U9/ t!zI59U3%r#e£bw	lVQ]*kf?éD:N1/’àG”;‘gTuwODd	X2Wq3Q3ezPN8.écRTCAe!uD—9er0u
# ----
# iter 0, loss: 113.582373
# ----
#  wIIwIk wIhI nIdIi?gIIa?tod
# aIw?wt
# IIwwI?I I  wI wIInsuIIwafi w CTwInInw?wdIIwwnIdIII iIa?wwioIwwwwIwwaInwHInwI
# nIIIwIwwa.?wIdInoI Ito ?
# If1?www  Iw ?IaIwt
# ?swIIIwww I nIIh?II o?woIIaw wwIwInw Iw nw ?
# ----
# iter 100, loss: 114.199369
# ----
#    tet. Hhha    .chrf wepsi n  di
#     e y iai d.od tn  p      nh e sacth. inxh  i n esduw  i he ex ei  htt  h de d t thd h hr nw g
# h h ht  e,  re  is cn  i k   r H ek  a
# yr
# iny eahhni  ni c i khl  e
# ----
# iter 200, loss: 111.088664
# ----
#   eap  f c sace   h  c
# nter c he?i ec  h  ha h o echci  cds n   ccet oc
# u  I
# heac   o
#  ?  gor.  oh”nh af tgcp t m tn o
#  t    hrcc  c   eca c,, pschc  ”o  haw oc e y fs   ae
# o]awb
# rchh hc fh ne
# h
# ----
# iter 300, loss: 107.931596
# ----
#   iir inhc yn  isnneevisa iabng anoviL d  n uityin in f    i en o aneonc inaihe iu egonui  en iranenInoNtie“r h _ie  uvhutionirrl t inuc reuc
# onwhia r
#  o ani anhharenokinbna in lhiln
# anrnivhencineoeis
# ----
# iter 400, loss: 105.223469
# ----
#  oeaa
# adam unhekeddvha “laotarsoSdn
# lyad
# ldg
#  au”dM“en, or    liy
#   ,  dla rk ir ,h if i es  heanmhk  gihet s yh  rsh sklggaA
# l dfolaandhk elaa
#  mak aleo, ts del saneyhdyamt “l“r  osDdafhhiheh, raa
# ----
# iter 500, loss: 102.258939
# ----
#  ,
#  iunal  ense csaridisirhoetosans p infiselecf“nfwuceyemasin bpun
# iw c ti
# c
# tsyaonon eh .afty f yan ahf hr h
# s toweL  istt ulonhimipiscpf, ssea
# c sNayarspotisc
# tylin scleise!n sn ho conceiseinr  mes
# ----
# iter 600, loss: 99.475345
# ----
#  ghe wswocannd ”d,haseule ccimomesp
# memh s,omcliced it  atearepos prarl
#  re  cinho d er4ises   ”tr lhmaedhin  ”tol  c
# i manre  m  obe.
# d“tneud
# db ccyhadeusic,ce btd cer lhudan tolc id s  he   th  s
# ----
# iter 700, loss: 96.854310
# ----
#  tow waf
#  felwhe ssanheg ami tew
#    cef
#   ileatetol tar war waren  Hheraw  oice      , u , dameaen
#    h   rl tot oxmie carad weh te uts w lh w  Haur teilamat  rinrk, the
#   Hlede
#  ele i s
# tilt th om
# ----
# iter 800, loss: 93.827181
# ----
#  ns  atha kor
#  tiId gg  are, . ivre   weid tesmel, yhhyis m
# d  thowh khi     kil lomer   pf font  wifod  it   inau fs mothaHg     hme thew  benthonhen slaw   dat  orot   rhakt         an  s the e me vo
# ----
# iter 900, loss: 90.636839
# ----
#  t Isat es    ta, Bhead hdowe
#    sho ssingags fed rhintor wed
# d    h oegseos , bhthoa hikd f  sunhifhaf   tif   shod garithoff fe2  arlf  of t htif fha    hegghftan thhenhef totathe se      he iny  ag
# ----
# iter 1000, loss: 87.702859
# ----
#   _ze
#   ben   se   Mly  in   s  e
#  t. ar i  Hire
#  “voccor I
# gorunomhelors   irN   c.
#  sh “oc“amnalor   he thtHyy it thyfalas
# asrlrhey ghe be  0eiu   d
#   in coune    pathe. Darhif ?y linpour
#   hiny
# ----
# iter 1100, loss: 85.214920
# ----
#  nhae cinslalle ssas ina’nsotdinusd wlipressole
#  minhew han   anoinalte walssedsaf alosatiinosmmind   nhasis
# ele thxsoptos pif    serestin   , bed  is  ren imenosdonv, hip TeOn iisweinlat siasvventenc
# ----
# iter 1200, loss: 83.070209
# ----
#  Cosyenicn smip   orl dr,akis on  d kisde
#   e slesohay sabnlariw’.    tesucecvoIt    eJnsinipy bat
#  sion
# wut   ere,e ppwdifhofs  tin lluns ikrlot
# wn’
# acot
# My    senn Cnnasgoenerwch      s   sess t
# ----
# iter 1300, loss: 80.740039
# ----
#       whifg whenoprgtonber r ihe sosofn rf“y  hogMcren ”d mre The tamseEl  otmoint    fo.     chitenrt onecgp gistq
#  . s”emican lons yœre If   onesdannTe mertl rustfanos
#  n
# , iicom horsut vind chis
# ----
# iter 1400, loss: 78.959935
# ----
#  w wy fad deshe penlraf irir
#   ir Iodde tosd tde   Ihofred Worder I azhasherm m, rord fed wheplhangiudv.hastony she medxourd wrers Hiuthirdang   t a or e    barian wha perxwisort Mur s orpar         ov
# ----
# iter 1500, loss: 77.378960
# ----
#  ee I
# thedse it  yuttid Hesdeld  . bee tatey the derordeoss Madrytaudtge
#  ar. Iny  athe  enpe edtel Heedend whtovserto wostiroBhereronyBund ane douBedourdyat atleedbid yan toy. orse
#  i. rig
#    uat wipe
# ----
# iter 1600, loss: 75.770556
# ----
#  hes
#  ““saopteNsoiswamswhon hexth,
# thi
#  ose wo. the
#  ske thofaed
#
# oorpimp thit eote d?. th
# rspay ixn thotilethurthon  or-btto”s e  t
#  s “the the shas
# memaay mximge
# pasetce ge e,Yon  w   e shutitheYe ba
# ----
# iter 1700, loss: 74.314726
# ----
#  stador an
#      merex
#    he hves fl-d ce khe th miss,        e tosonilarlaprlte Thanceells thondellwmetd   basgplssildnp-nusdinenndurndHosnosd thekk fherir.-ler,   cng. d
#            we. canfame he mou
# ----
# iter 1800, loss: 73.068611
# ----
#  di tun wu hg she
#  I Bore thaw
#          Chomthe
# g “oot me he whovy ho
# ptfosen “o th
#        oeos Werem hohu gh    oydaulmas mo mrod
#         Thh, B  a
# aund Iihshit on a thiy thex. Coapvl Sor        “t
# ----
# iter 1900, loss: 71.811951
# ----
#  e        os wicores fonkat Shith thlitbipid me this   sedthioole cog irre ated. cthed rhe the.”
# t  e y     tu hatiEse hewrve tesop tke th  Se te
#
#  foasd Mpe t     i
#
#  f . whe
#
#   oulpir be
#           ,
# ----
# iter 2000, loss: 70.656763
# ----
#  d wour srepot y beAw IdIthoushener  be, al bhlers uus.”
#
#
#   “benather tobon ouAclat thyisHorhabyvhoussed ire shure”
# HacaMuout  e  ome waI Thilutheur awye”a .   iyilexwer, Yr,.    ohe            rof?at
# ----
# iter 2100, loss: 69.653189
# ----
#   iy y
#   aury yre gfe teed wat pon”wrferid ben s latandeeves fus dassestyiteres
#
#          “benr.9nles The matitm Thin
#   r, huvheanTThir, thaevedend svos aas akse  lodire.”
# osene I H m ooveldtest
# ----
# iter 2200, loss: 68.614885
# ----
#           ha ants disvenortes habe wous bul   i,        winl. hhe , w  as anenllr thstadstsesitpool
#
#
#        f bTon wfpod hoare by tae the h        th
#
#
#
#  at. the
#
#
#                han. so
# ----
# iter 2300, loss: 67.423717
# ----
#  hekeoun ase soft  theng be hhusonve uucdsenole,he tot bon. Sand Mnet, be ae 6f Htecit crerin 7ore hrachil.” cre asid of Nos hoorse or Th  Bohend     hat in invemithendas     Mig”
#
#     t
# s
#  rond
#    id
# ----
# iter 2400, loss: 66.561309
# ----
#  “il
#                yin
#
#
#  “y soaglins. ye,, pn”
#
#   wimeal.   ther theorice gary on. fsis He theuls of?f whe covorge ef be or inhiss of Af in tfas ikes igeeton theg al
#       sind on itht?d tof an sher.
# ----
# iter 2500, loss: 65.885920
# ----
#  presn_ _fe
#       yDre?ge th   sil_?e fe _”
#
#
# ae oup_evt imen the to gere naves gan_ severe qure _y ag ild rooge on   _ori_ sirevestre tee in_s Meed boxm whe or _iwely I eyll_s w thyerkend yus _e oacas
# ----
# iter 2600, loss: 65.286545
# ----
#  ew, bot wol -n Morse the tf hisdillys as shichs ce incers. mot towebs il riy yer aatee th therere ine th— therd
#    “I owe Dhe the le?t  sos ure cithich fiilskenild  is  hor
#
#
#       pe titxd ye
# se se i
# ----
# iter 2700, loss: 64.576674
# ----
#   time “soe
#  “yhle thofre Afdirtinh “theet stt”
#   ived I Yot tod
#     ty he
#
#  ouh fin y wherne hfave fret
#   y so fhe Ch s“pven und “t ou the whe nollin. wu had Oucsthd
#   irret  canpon it
#   n es, rhery t
# ----
# iter 2800, loss: 63.810146
# ----
#  gof wa’neeceece’syapf lmit wcanr of tf any tofr?”sgr Dh sa’ke—   rardefto avls’ved yibnd pan him, vefbis et Mod se thinl. bes os inder
#      to is     umis I hallenive,
#
#  hiunarele I anme’lanpftighy, m
# ----
# iter 2900, loss: 63.049132
# ----
#  “it yatt the se O! Inctousicoras De san. thed bevoc dew, y We at cor Wofralast sfan     yte
#     ”
#
#
#      g our YariWh agi
#
#       ont to ped
#   be, I mapr hos Din mor, f that    poghecit of th Hafine. s
# ----
# iter 3000, loss: 62.432694
# ----
#  put!overclathe sewowris whenle
#   harte anin”
#      “I Heston ’t the pit .”
#
#       pactiswisoof thaved torim a leuplomemstitey, Hirooche bathureatAa,toutetnobem whe is somer wout’ly Wvthre seat tus an”
#
# ----
# iter 3100, loss: 61.992432
# ----
#
#           as wuotfath wu geniuchigiinh moat an          hthir tulNmortuag ou mol biiut thitgve manmemYpine-hay. israth it se the dvelce tne beaicwen” sitf anvis att oriranginrdres
#       Nasin
# ----
# iter 3200, loss: 61.436446
# ----
#  ming an goarser ereld
#      Thet Arip?iek ge cille the sareg an-simes     arele sasy shesoan y i pals he orgae??Ttend woriols          gaigmelwace shy
# Tfer. was a of
#    “The mory igd whe thil hith mir
# ----
# iter 3300, loss: 60.777970
# ----
#   iye So
#  y Thet ag host siim “peot has ” te wepestivit oavivcans. wissms thenkiteocuf ccteag, wach u in
#
#     he unes at yotn,
#  “Hecot,
#    ionactimyeis Nt apse to”
#         “pnyits e. pangy whe
#      “T
# ----
# iter 3400, loss: 60.468765
# ----
#  ld unant, younin??Wy jonce mou oos’, we ooers oxat s yean utes Wam. chat ter yavoft  merineRjinyem, in’inneid in’cle y—ty houvers Imeud ineyysure?’Nt ank crefteithen’ingeny ind on yetey naf”
#
#  inimd s
# ----
# iter 3500, loss: 59.950358
# ----
#  toe Sat ald an lera.hag thes anBaek tionl dow ineiw fordar         “‘uocarainilelkheasm ard fen there Ge Gad  h Dre’d, Batg ran thad be kur.y the gis aderonretoraiBand ravean wang poren, wl, , anslow
# ----
# iter 3600, loss: 59.593553
# ----
#  h Che houre Che mes ill anleTh the wos has weme lun ar anded she ltpy th be the ide rund to tost he he,, wo.gectimomecw love ewd thest wfe in wiveerpos antoheuird we!t we
#   o of thenlead. Hselepin
#
# ----
# iter 3700, loss: 59.165592
# ----
#  t altiu
#    “Ito qr
#    oale wis I se anal tit anutixy a fad silde wilafe yous aEe of mal How’ltrpeillemm thatases y Howkave tiellmeviksl hImleicol nope mos Buletd wimal.
#       I we lirh wow Thisle saot
# ----
# iter 3800, loss: 58.758824
# ----
#   tun Sassity, thiy chunt RoyB tfaroct en wos ciwr uneets    nh arat.”
#
#      wos             suil Tu I haglong rummang art yrat. ma wossem Tinre ho thas asec yas rad biw
#     I“   wr. to  ou frablad at
# ----
# iter 3900, loss: 58.618087
# ----
#  altd bhe bund rrFe encencetcin,”
#
#  fenor in
#              “I
#   “Mhanlerestaus on, I Wad themmet rntsle heshe wang Hi, sen th as ricd fat ablifinde m addste s  thentnd ancer benst. kpeng, thuv sofmcy y
# ----
# iter 4000, loss: 58.266457
# ----
#  the anad I gain I mSo gor to gole hin ofe or, becne
#       “Bney ing thong”
#
#  “Gnongy
#   ence thenred a ciy
#       ghe ore Rimy goun ano Hang fin.”ted why t
#    y“yto’d tho thlenge  any simow on youre
# ----
# iter 4100, loss: 57.990753
# ----
#  t w ot vepreiow yer Bit cet             ow ore an I Baterlat u er up guthe gou tier a yeorsserile te to thef rourk I her mustiche tounm cer that why peewy in the
# Grat theaced by uy or wansillve ke in
# ----
# iter 4200, loss: 57.769182
# ----
#  ur hout ind as seren ofiriild pavs ?”
#
#       o  the
#      haver Srhed indstolgf se Bfe th! ofe ance y agmou hat Me anleseves thas ing ain ws ne lat a of wof dan manlest atcauf irqwmin
#           thath f
# ----
# iter 4300, loss: 57.470384
# ----
#  sgarlad
#
#  anpe yee, of to he hin
#         terem t   fordof oaedopnskerere toue tasfer norhe fof of ce alar’
#
#  Theind thad, felly fine of fer than, u dore -on wereilben id meutt I Dom pe?”ssawg an
#   ’ w
# ----
# iter 4400, loss: 57.289672
# ----
#   Age guelith er
#    gare howte yoar of Thett bersissave lavertiad saluutr ang theskorgaurtme sallenuerengeake of
#
#    felenowt age jad astod lolbirenthid-yas. wler to cerered astargereraleve thof oimeor
# ----
# iter 4500, loss: 57.262935
# ----
#  ugne thatl hime heotund h whasittinr rund o.”
#
#        Cod
#    soty oe. wicogaevoud to dencens
#    igk,
#   tolt beet nese lougd
#      To it moloud tnes, bererycilliciune wuslalougl of in sons urr noll
#   bo
# ----
# iter 4600, loss: 56.893468
# ----
#  oodend the ours                       “ekl manakedery
#
#  hes wich cre the crut vesce.”
#
#      he ind Wheus cot shin
#    thindendy haseend lhes ash th mert   “Wercisoong or herde baces mlot llan mo
# ----
# iter 4700, loss: 56.727276
# ----
#  nd tayelt       art oues whedrest outt at tordilredd lunlae thake har.”
#
#          pore. sa hiorleene
#     ant le, file indey waeh hones ibks wwat wy fotdedathor. ounl frer msyand urin or ttind
#   a thon
# ----
# iter 4800, loss: 56.487029
# ----
#  heoseew, with Yeaw  “Tfacie. Be. hae’de in _ivis gremeisse “Ar asengy blvelbo twest nandetsatd riteoles is ye and screis an wouud cfsade ripenkeed of ho t sacssle ips bolaed con
#              deele e t
# ----
# iter 4900, loss: 56.286406
# ----
#  irs vooweltmalles
#   angsrellek ild Aed
#  wad tand
#   mitfr oondleronde tcamelog anske angt of comerpreencifledD hoeghilg yadomecdes oundpelch inenlly thomlwiTtcpe cos,
#     of biteemiselt our
#  srearla, t
# ----
# iter 5000, loss: 56.102104
# ----
#  t, the thrusk Awle wimenrerod balonson the had merew ant ache oarhe ratl jo, ber eim
#      phasthe cat dirangise frem beenetded che cey a Cabed the end cymomghoochet wead -ewe,t ob-ss statae memleng! B
# ----
# iter 5100, loss: 55.839402
# ----
#  av! ne hond fog’
#      sen blove ise an The
#           no kfre the lunl
#      vin u nous
#     Mes Les sping boper hey in the las ancir co sfin c ctil the I gaif the
#      Wakky ang
#       “ir in Wod to thig
# ----
# iter 5200, loss: 55.625017
# ----
#  urssy at y sonit fer c th I the trenlenitl. I
#    hit un un alh thake pyet Hort bur efass as mer Sils pot
#     “Wo bow of to chirind lisiste, wipe f Eret bte I he t   the mere quplis nllladn Sen wave of
# ----
# iter 5300, loss: 55.471032
# ----
#  ired ustl  oft trir asaly in, pome to throleve u hes Moran
#    Se cy to we ipmen gid, you the irvut por yars Whive un
#   coangonnetty fis oollicoary ssy.r podcitems
#         fr, I had th
#
#  “Hmilde ce th
#
# ----
# iter 5400, loss: 55.131089
# ----
#  noryin?” k.lipet in le?” preldeet boree fa, Mm nlible ghowcerer. Mor griy             Drimather,
#    “It qf anle
#                Gpre bobe tat wfgers no,e th.”
# p Yoon,’s le, Dt Theh the toat is the her
# ----
# iter 5500, loss: 55.025643
# ----
#  nd youd wfres oxve, I     hoatk anler.
#    “I c you I ?”
#
#      t drestode. bed ibls.
#    lorssaly
#        is ime sile
#      ousiuveorar , sheet thaln, thaf the out Wouk Mome bas pa coondooy prunr or oo i
# ----
# iter 5600, loss: 54.839124
# ----
#  dty qureis aghe  nniutkan sid, me thad ang hirs of alde
#   “   Wonr hitctatt surt the he, als u wareuss sunstd nry I siat thit was “Sung tist hit the mithousadglat orzutrfucheppwefnd
#
#
#      doug heri
# ----
# iter 5700, loss: 54.753145
# ----
#  ed on Lad ibldcalddad he cose .”
#
#    car —pe
#     “Win fo to lod, the
#       “I haky
#          hy ciiceem hy
#      hathad astgiw pome dar gath
#     maseaceamiit the Lolit, ccend.dheod sther on the yhenk to
# ----
# iter 5800, loss: 54.679340
# ----
#  honde mo ghom papcibuealt tarw. Wot  “is un if dand “Inmet poin”
#
#     “Woldis dis me wherdolt bor, you tuef blime routmarliuliwd hou,”
#         anomglend to to , thuvileithitg enuke pod rel.
#     “qwiul
# ----
# iter 5900, loss: 54.588038
# ----
#   cparlurt yfalt to ant
#     yor id his and youn”
#          ader and me aos fleseius dind dend hoog was anghaon titho,.
#
#           I done of oos blm. sh sor se hoeg wwer tk, of siped to aves lertont waer
# ----
# iter 6000, loss: 54.484001
# ----
#           had angleomy mert roun.
#       Dnwicuveselmle the, Sy cuds ound
#
#       ullcourewith hourd ouchat forcof
#          hithgund your Hon of hit and he hasar, und surtay of the owens siss weakeurer
#
#
# ----
# iter 6100, loss: 54.191277
# ----
#  thBsHs
#        sher nor
#  of Thos he henttin ofsache my
#  ang Fuly havy wohe no matkeon
#       “Wit gort in
#    “Whaven Hof or ans thy larpy sorglaticoilethroonedk frkokttinche ch besRryoorerogn
#   fas sons
# ----
# iter 6200, loss: 54.232044
# ----
#    Acaren. Th ult bag ton
#       hevlidt ogzave atseng hentelsel, thass eed laes, allen oT atlabt on afp. bouny Bf meve tuI, oo buth ssinn, ald fogulqat     houvoreveng Dange blateice ths of asilout Yed
# ----
# iter 6300, loss: 54.026924
# ----
#  nlat fhe vuvey fovillese sesl of couke gighesllexklrris was chy
#         fe, mor wfinke.rlind the
#      serhim of aos e hause cus foded sat thite kosswapls a ded of ud dtless he slaind be eath anloose u
# ----
# iter 6400, loss: 53.897949
# ----
#  n
#    ait’mereserate the ag, irrot word ther, the warprous ther so ras mad the winget-oncy the tone bus.d fir mat een dert a eitkid poocyee the dargadd
#       mipde. whe isted. Th ort amapat     Se. the
# ----
# iter 6500, loss: 53.926269
# ----
#  e nour ind the inuse he thars to to sest on uschargue
#          nocsonges o the ncilour strearemiper toncner It, thy o as thithere rourginwor, allter stich thith mo weretcos. cos wweplcure four the the
# ----
# iter 6600, loss: 53.916375
# ----
#  abs c somacre c nutrit t joD wangwith sar is the
#          he me th an
#          man tarm.
#       meun cond afreing
#     xfes
#         issy nwtat blus ripiod worpy bn, boms he be vikerpy mown
#           boo
# ----
# iter 6700, loss: 53.801995
# ----
#  hicr Her hacn some thaghis wad his dals ben un yoursc. younve time save andersreld the solrnoris anNery waog fo. Bt stathin
#       te
#   o womelf mat
#   the mascy
#      of I gods un ton
#       no to      m
# ----
# iter 6800, loss: 53.543600
# ----
#   to antong ryeft chast rneon
#
#       penkd  nathed ras gory a rootiwe meyk on aco the lupll he toun thobd fos fof mereem
#   The tfore do dourne vet. Bushene yfoetht, the dootiroabtile hat hish, ouverd s
# ----
# iter 6900, loss: 53.588123
# ----
#  coxthe rithewiscavpy a ofibses no
#    sed whemin tuy
#       ipopponstorendpome ux doulteurecingoundwes crats afar tont iaks
#       Beucain” fatire bore
#    nuset. aittlome ale hached me thace esiropror,
# ----
# iter 7000, loss: 53.501321
# ----
#  hit hot shes he yakvord mre wich mand achin sod that houy halet ox ruen
#   nowcillce anthes wowkm stefn it se on hhect youctansss sod mat satomercay mes wis rorentt  he olivesthprerfIst towt, tissem ho
# ----
# iter 7100, loss: 53.302597
# ----
#  mat w deencour lnod thigte Hianvy theod illo the nacatinuthearcel, nis ant rat analk anges boutd sen toe
#      guloler lioingilhet and aellis nolat
#       tish, bre noin
#       Theftour bututhe eay noghy
# ----
# iter 7200, loss: 53.130799
# ----
#  le, whe we hat ge shuy “Wond     skeres I me sy ohet Whon?” se—teur o hiotn te he and to walle mu, wa, Mos thear han wlot toy
#       file wet of’s he lanl it haw  o he
#        ir sus thich wut red et yo
# ----
# iter 7300, loss: 52.967617
# ----
#  xrtaw     snon to     ofor vets Hoss a iaf
#     tite int a and Hacey as of ty a khacinge ?I cass
#     ecost sta thieravitt wite ror. rise I mo
#       I fit mis. ghane
#     hiviad Shar utcour frhive the
#
# ----
# iter 7400, loss: 52.786752
# ----
#  wat id yrat
#       jy wowl so nee himgat ritwecst mat and the.” ghy he hadd wan
#       ber the         wun’gw o swelavatnle hisult dy ser, winr seyystaf’g wos hint wigone wmot.     shewifted cat we dat
# ----
# iter 7500, loss: 52.566081
# ----
#  ais his mat, wis, thes. He twemy, wild bod he mat pris mo anso wh and suran spe poberinc s, at and iW stach here ryof mo chondene te siny wrowh. ef shoss ghotho badtin opach me
#      rend eres, wod,, s
# ----
# iter 7600, loss: 52.471047
# ----
#       nress, and.my youggsowrave it th, yong wut wiwer th
#        fonoy y I pat you ny fate corpag dy I u lost,
#       “the
# t “I s. Wo,”
#         noconnpuntland yiocelemit, qu what nounliuntuld ancimes as
# ----
# iter 7700, loss: 52.309048
# ----
#  re was waschans adreebks, un our, wirop dimle bmamet is was roirty widd, bre to le biud ris
#  he ely was a the and the thy wanly
#       Ted thissy fren ritdmas ta dos aed, ther     e the or sher Hy ce.
#
# ----
# iter 7800, loss: 52.063933
# ----
#
#
#    th anom his gtroud why me mert me the at int hy lund buc,       or youke. thad yigat ig thekemomer I hy bhisristerbad thaticoann. Hor the
#    ou doon ad sag. ive wuph. Ig     wior wlron foudga
# ----
# iter 7900, loss: 51.820090
# ----
#   food “On?”
#       Nount?” . Bir of
#       fe coist!”
#     e su the fe toG dor the the hasirat dosicho ore Bin Dlet lime wus  it the bee cery elolen A whonree the doselte the hy shated on tiaolath somy
# ----
# iter 8000, loss: 51.534361
# ----
#
#       saddar ner the cace.”
#
#       pad wach, oulkmeid it the gascet. Witleakidn hien wmrars amdeat toico dor. Wirlrinvess mers afde
#  you cas noly pooicringelde ip we whe rouskan in a it insk this sin
# ----
# iter 8100, loss: 51.301849
# ----
#  matk of wuplem snid tut le wheddif andaly
#   The ga and tceulTsen wat herours cis
#       thmsstw in ar an
#       on. anvniur. le And, foull molve wond thall he melled ankond vigl burl he on to ta dil an
#
# ----
# iter 8200, loss: 51.236171
# ----
#   a wowd.
#       ren
#       av. Our wtet  he cut fom der not he nepevew, the
#       mipl. the houpy of thowp wat, asitemicowh waonltemt. Thersins. I honss it pind anle I luscimat
#    codemtout whald has to
# ----
# iter 8300, loss: 51.118374
# ----
#  t thasr mer.      he not pact fis to thasate of cfure afde maptod mrod
#
#       I thaogt gat the
#       if gutl stron firsrers afd achind of as nave of a of and to thech un the
#    o ce the to dich.
#
# ----
# iter 8400, loss: 51.136231
# ----
#  eat is. It mat to nuecseenif wefpenen
#
#       pitr lut ag st.
#    ste heatd her us muThecer, bols denplive atmilledery roan. I vyon on tuas hiifipull boulyod ce oficithis is ncoure onves ir thes un tha
# ----
# iter 8500, loss: 51.022700
# ----
#  the fanovisstor bes is dor, anels cive
#   Sf Fo
#
#  jathams ang win val y ckald     i“seve b-ger
#  no
#           igp herse; I he be has that “The thlat walrilr bevet a wesl to looc that us wive las nor
# ----
# iter 8600, loss: 51.007716
# ----
#  that yom nlyoblle warany yor enlerslend way Hone. I dand thenit?”s, I guratcildte, min falat _od nach broonrste Het then itm, and sine in walnsis witarund oo grro siso wneg my ber ane in a what ungeer
# ----
# iter 8700, loss: 50.820428
# ----
#  t mente
#       In in thil
#   mer at of vlt
#       nemkcor ot the thed nur in
#       fmace th totn”
#
#   “Wereventiw at Was soow thaft It waot oule u cect be don the it moutht. A wouce
#       ath of worl age
# ----
# iter 8800, loss: 50.722553
# ----
#   halRat
#       “I’sh be dasd mat he
#       qlin horlr nfants, thoce
#     “I ce. I me ald hichen Laged hin I noms w I guss, to ous higefter.
#       in thast oat the ag?gyHy I hing mive. I
#       tuco ar lav
# ----
# iter 8900, loss: 50.796936
# ----
#  urseeso lomek biy, grinuld of am I hy lole
#       tled y try ex. Fincit fos. The
#       Hevs c, chavlo notd tiyy the dprune sadens . Thigglictichit thon Foaccy he on
#       “W’teive way tioc ind ald hiut
# ----
# iter 9000, loss: 50.993691
# ----
#   “Nowron bos sonee at nolke’m the hat sharat therk of wilvoaky gown sipols nit ass your wit and
#    “I has pur’sy wh.”
#
#           uprer’s u ceed
#  Bok maude Hos Bpor.
#        “I -pind to that’s, impecs d
# ----
# iter 9100, loss: 50.876015
# ----
#  laoke mabdat by ancroepeld sed y fore Cmem he foraf fall hiWde
#       nomtesf hat arare, ath of yoa se coceuthso, race wancind and Lucoubd one
#     Sesgat ancurmimoolkl fasles.
#       avach Lact, bec tob
# ----
# iter 9200, loss: 50.730623
# ----
#  nd unger and coukighith rem. Ars and toths the fes the to, mavy frich the she his
#       Miche mas bund afste tu”
#  etta,, me y ansstomer I cich theteringbmomgomel. Tnind
#       he
#       her sowlone thak
# ----
# iter 9300, loss: 50.796407
# ----
#  rres otras imer of ing tepont
#       the
#       toer.”
#
#
#       the the aniby.”
#
#     sirtoseat Chas se of ane, at
#       qistuidery jot Chate mich mashad Sitt ktenakendt dall the
#       weyto
#    “Vut Are l
# ----
# iter 9400, loss: 50.672284
# ----
#  ces be he viuly w and ave alitey thir
#
#       “I we cain Hin Sartan wis aselet mat?”
#  tas ait “Yoog nat hinly g tiet belciingay I,”
#
#       ipliliy. Whe brincidh prmin ne ty qry trout fre ciy atss he
# ----
# iter 9500, loss: 50.555537
# ----
#  l
#       what bof aced whoty etad meve     meres harloulve. feny ous repand the hastavistads the if aplpilees     on you tuincasteice oud
#       chate durlaircaneack I er lereuch I utragcher to toly ere
# ----
# iter 9600, loss: 50.298075
# ----
#  odas tisgins Mis, dev of oft in thid thar kutidm, erit tuet the
#       nousterd a heod of bed, a hat vend and    stin. and herenery the meudd
#       indit of ow me-tithald fus heckidtings ind hed if ati
# ----
# iter 9700, loss: 50.228143
# ----
#  d I this heed the hery Sa fandcenat £eptend lir inoitk.d ip tu ney th thAurteacl. Tteponilat on, you bereoret ante.
#
#       inive carlerson theck of beut. oilitk frouretsyafsiullm the
#       a the dofas
# ----
# iter 9800, loss: 50.408516
# ----
#       yout round-ky hhe you
#       Brour.
#
#       aonWycoung the no( thavork oups apagktioch miye of gpaby then lerk faveefrateiy with hime the
#    “Yermof. It mas atse thocle aed ur
#
#       olitked oond s
# ----
# iter 9900, loss: 50.301558
# ----
#  y I Wrfatl forh. Fots ouve mo wreg wichy i genly
#       bello to liut sicr dusn were thl
#       hecl
#       thy fus hal. Wisy it’s’y en a o e ave hich Pond aneng un n tu cer favimm the lar the hang ! ut
# ----
# iter 10000, loss: 50.364693
# ----
#  vyakn save butove thut nelen, foulk meofber the btile shad the do. I o alavf rer. A fmaco wpevich-pelin Blet cem she plase of ant ancheyinvery se thatgaprnow dey_as nore put Bat stoust anole nest vive
# ----
# iter 10100, loss: 50.283813
# ----
#  y wpand thond, wute the lm. Ad, fneg he sherathtiiced It, whis to the wlon
#       eallind, fond wwy upor wos on
#       idsen to mupwdemtwouwer ta,
#       dublaon habind mit thasth
#       fowsas harn forac
# ----
# iter 10200, loss: 50.214326
# ----
#   whes and sher. Mere o
#
#       wume soy ine
#       “he
#
#       lavice ly he was mave whe”
#
#       t lale he acilm cuuth plis of gwen wast in rome nont wheil thitile res mo me has the—lering sketrlenedte h
# ----
# iter 10300, loss: 50.251918
# ----
#  the lry prenher kar wrat that lock may. Yeet tha! It I wam is the eby theut. Thad the fad that whe fhat?”
#
#       wackindyonmy thaekeshicl, lapl, the whil , I gadeet Ho thit hachet I hele wat whe ly Ch
# ----
# iter 10400, loss: 50.169439
# ----
#   the cer mome whar a rers and co mous rr yreat the bund ris are lat hiint mases fringy frem ohvair whot in it id mo ole
#       thow yoorlas y has unald leth aro rat pigs corer is wflonver.”
#
#       _us
# ----
# iter 10500, loss: 50.041498
# ----
#  tl I dolnefyakon to meuy toulpenefoot boverfan of mSended “fentilay “frad upoll in, aninitom, wonemimes frons
#       on?”
#    to that of wilfinges.”
#
#       afvhed—yeLlich anand—band af
#       “ffimyoxon
# ----
# iter 10600, loss: 50.026889
# ----
#  e this ostar iste ane in so sloce, As asy desh atkica—shather oveaon and cor Hpagey lad So be warer. a he to sa—we there I ly tham fer—The tof Heet whes? I loat Let woobly hew—utloreas simtenco tr—on
# ----
# iter 10700, loss: 50.128724
# ----
#   wall noogirvom ot of hadd. The athet ganged
#
#      sory mory herssed neind the. Yagns ave hat hood cus
#     eell the
#       solped a sooked unsnes hiwe-ris ans, I dyom cy ofV. The h ore yat nons
#       A
# ----
# iter 10800, loss: 50.140819
# ----
#        shoron bows bheng thy suid mat Cheust int the het fre?”
# k the she hach srot! a shatd dor hasd, it utonghe
#       “It is hache ang, whe nouttson the bend     hime hid un?”
#
#      f, the rarde hanto
# ----
# iter 10900, loss: 50.038526
# ----
#  ato fatcyed was blon pigh unber
#       “Not couogs a hidewwange hat asn Af
#       obeastens, a bood freer. I hadem my deodithan
#       “We?”
#
#   “the poolcibeed so kping. Loof?”
# t sets
#       We be the on
# ----
# iter 11000, loss: 49.977127
# ----
#  nok sroulyut tous diog wileuld ras in mizol?”
#
#       shary.”
#
#       hos blcinng in bond ous sed spollenn
#       ond Sin?Ath ipsis! Wy
#       selogtel. che upoufcach. A ow mopl”
#       I fcoorns
#       oab
# ----
# iter 11100, loss: 49.879873
# ----
#  s ntet to
#       “I to srior it te upouble
#       Thath I heand is the
#       on I roupalle ons pigh “and coDk noat to otith be
#       the l”
#
#       hein mo Horem are
#    “Yay.     to uid. fto Ry. “Wesy th
# ----
# iter 11200, loss: 49.787384
# ----
#  e waomod fow hy cesd a dein the hLe mes and
#       cosgeant it I tofy he have wiowave mour you ave nos hon to of he f
#       shond the
#       thatpros bat the miid on
#       sirk nompend tat ?”
#
#       mis
# ----
# iter 11300, loss: 49.779224
# ----
#            fers. A we ma wam nof be oo bel. We inted.”
#
#             thinn’t brace enten hat haesow er mond .               wpene soen
#
#       se u of ast. A a ste that waen whing. Se in frokerWdero foup
# ----
# iter 11400, loss: 49.602505
# ----
#  istidacractith ctats yoly nongryon ig. Boc’lein’s whiakm Bade tow thomy ary bet wifrroclyceld har to grouch he he son
#       las But oonscall abmave hey you dlow So mronlithy thiteare
#       sk mencayot
# ----
# iter 11500, loss: 49.616605
# ----
#  her are suwt wulling of Che couet the uly haodrey an our dalt a be afthene?”
#       “I das ald
# wimow thaty alled role mnoleow, owon come it apeme
#       in re pliiggringofes at  forved waef a bee bes n“
# ----
# iter 11600, loss: 49.588418
# ----
#  hon
#       “I gorgood coupet hlon biolichy oasiuve and sty. I hach iss that his I owith ircur. Wisss-ispadcaribet the
#       the in.”
#
#       afvimshe shisbidy be hout.”
#
#       sitle was the thesbing, fa
# ----
# iter 11700, loss: 49.597853
# ----
#  eytink
#       relin slhe wibgeed hewny”
# s flacy pante of farcer ganed. We chotdath fon. Anes haytlenty my te I keot ry, me yobitk
#       tneilite you ith. Howe Ited that sgon nus Afanew thand in ox as.
# ----
# iter 11800, loss: 49.525080
# ----
#  bliny cemat I coaf is ble meab the and nut bpeave the do couussile wulgulle litw thin rosey toonse and he math are thy a elpSer am, ir and wiskbantiiwas wo a cond
#      warey bo sto abe and eeere pout’
# ----
# iter 11900, loss: 49.328491
# ----
#  you w ugace cock,.
#
#       “Ase ppll wharland thim. We hoss. I boof mouly hew yinf in parls
#       “Itd
#       ilksinr in a cise fossancy the nedinsed. Whemy anmendesindeneer difficlus the. Thatenence tu
# ----
# iter 12000, loss: 49.317024
# ----
#  mat as hassere lave his and Bf I yourl afing ens benrsy wime thathat nols Hlid sulle. Its shesld eny aog and Dots rerlingorvucve hiund asselcey witht shas ther ae! I en. Her yow, thet engeyeup neslese
# ----
# iter 12100, loss: 49.423168
# ----
#  k and whandoun
#       the nrokens of no
#       wat lave donr.”
#
#       civelandy in all
#       “A’med, afad as
#       gerongs. pit anbyon withoras     be ar the cy he now” nom. Yfas and sur
#       “Nocho fo
# ----
# iter 12200, loss: 49.408257
# ----
#     plyedenit . Thy Mr.
#       sellet sur rreand
#     trould.
#    cfed. I
#       tert whee is it meter nut jnk ur
#     rrow of res sye, por, wlet to the ylat,
#       the I wertartas to waren, wo seRtsest and
# ----
# iter 12300, loss: 49.479448
# ----
#  h of asy his o siung the ip talh the reit hime wastoIpenipe,
#       _on foult and fforenery ktion for, ig of the mattid thep hats obe hely min,
#       dole he shace o dive the led stinceline and has mis
# ----
# iter 12400, loss: 49.357968
# ----
#  od sils to that ote ghive souns. The fave agohy, woriestincen mere, hert.
#
#
#       stouler bek-role foss sed
#       oc ondincescionhy forill wat ing angy n manasterhre des thy
#       mandy. in
#       cose
# ----
# iter 12500, loss: 49.290555
# ----
#  are and hhes ing garlefnet wairg the waderry and anl qhacr ave ton tupeg
#       warnld
#       ggald in was s agl, promeungont it bot wull. By eas, befing?”
#   oneine ande
#       Thean was. Butt ’n the nut
# ----
# iter 12600, loss: 49.261308
# ----
#  s ing anatld rhos led, the. Snere wisth a dineand hin of mirh
#        shennaign
#
#       ge had ze eurde dall
#
#   a
#       Thouspent worte feree ktelt if I henner mad dan
#       sind. Hacipot nut erdengh
# ----
# iter 12700, loss: 49.300761
# ----
#   an, vin seat o to marde wave and micoices Hur?
#
#       “Bathes mar the and “   “We my go dufin indtec
#       i had
#       ras der.”
#
#       “Hed saf, tha. “ta
#       in shat tooct. Ath is ovenny the munt
# ----
# iter 12800, loss: 49.276683
# ----
#    shese fat ame
#      ” Hin cenhes. Thic.”
#
#      ser—assserored 6holly
#       She it w” ond danh.
#
#
#       “Enfy nos.
#
#       amd nfes avexbge aad
#       “Yis as an, wreds dess thas beed ace
#
#       heing,”
# ----
# iter 12900, loss: 49.195217
# ----
#   be blos he mearouttes nrem ladt fedtertered and trar the, the enteat     Hoallerinde hod hhe
#       ““The lome on
#       erd oAre war. It the the,” dad. Sin afag hiwhe hiIc ge siy at melert Weved ir we
# ----
# iter 13000, loss: 49.053643
# ----
#  e ceinet fred orpincinlmraprirnyet the ur we taplhes. What to stet lighe
#       the. The tide, shh noms then wighedtish and thichy wurlleit
#       Mr oh fing sitnek thas farifeand taut vered wighisk thi
# ----
# iter 13100, loss: 49.125569
# ----
#  ave un” thios you hend orath, a ouco the hvmlt goned he he
#  stat wave ky dalon sy, is all wled.”
#
#     sifos     mant ind This sazer, and che hat stee toonditk sore hif iigeamd turouppand as he to wuvo
# ----
# iter 13200, loss: 49.245354
# ----
#  sn-heng herhasn the wavinntteed it se me cisheste.
#       You and I usterevl,
#       Nres and brols so
#       “The aninm itltnithaco. Henteerce’dtten, the ingifawtingal”
#       wime slriniteon cull. Ne ha
# ----
# iter 13300, loss: 49.416506
# ----
#  d youtherenstis
#     “I zifneves to cooB bfaratlr
#       “Oied in thut ass in wase bareirnqun
#       withertomd is
#       wher to to wail; nold tolendedenild in wesich mut ente oo bed. ointe ol
#       shaz
# ----
# iter 13400, loss: 49.569754
# ----
#  s ghe warlt wuth whald and the mighet haey
#       that I jattisl nut mowe Roudam. Sharle
#       hallave deal to gan.ing of to the hroms ghee theuleast be hiih. The ay the pery shin wave eply mat tols. a
# ----
# iter 13500, loss: 49.499625
# ----
#  idceacef wat on vid hat a saas Costearf thy t. Gos dy werpaling a on the wrHinid ach prirrabn Chedtideit a mgave Had tling lascripad afmy wiplargont the
#    Baulet inac mult. oce. “Nond map grastyinge
# ----
# iter 13600, loss: 49.435464
# ----
#   suen bule
#       her the
#       is blore the hiont waon in. wovive her fad thitherl donr the the
#       Heavon mat of ta fed fal uls his and whound ont and is the n mowut
#     stm. I fowe,
#       “welle b
# ----
# iter 13700, loss: 49.485224
# ----
#  pmdellesened Laogdae bgoreoger be hes kinge
#       waseat nole allerandol the and the wan andogebedtinging frow fad the lelce f Mase the it butd ot in
#       frer forosvrormen hourd mor opros
#       oode
# ----
# iter 13800, loss: 49.491376
# ----
#   ctey ardinconcun
#       cret.”
#
#       ofter we.ios mouscomereny. Homeghttat daondency bemexrey, fot fet lll
#       and tur ghy thacuml. The I oncing istly wincimeer to corpome ateiwt. Sa cnoutsercom st
# ----
# iter 13900, loss: 49.477134
# ----
#   on, to gouack,
#       the sument Thersing in
#       he now wacceppat he beed we wxagsoas ceallSer nranee
#       beey so ded pon
#       es at pran er ibsbly sy a f-cacher of aft oit oveh. I gat a co Ser m
# ----
# iter 14000, loss: 49.463638
# ----
#   lassos yBat o mowl a havyinect of of ins cy of that on awers enonry cealy upse,
#       yond, Eald the and therk Seacered mat ut aple ane ance his coulrede to sare, Hiret chaup core Ml me tur
#       tri
# ----
# iter 14100, loss: 49.285171
# ----
#  **.”
#
#  ho* y*To*thind *x*s*a* beak B*jnO****tiit *prougarTe
#   pe **_V* *ath *rid *ust gat*.
#  hitls.*OE*,”*e
#
#  t **and *id. *E in buchy wot waist ****. I* th** Thel, of ga*t *fop Dm,.live.”
#  hing**ifO,
# ----
# iter 14200, loss: 50.074516
# ----
#   Ociutare cay. bos 1tticring oore lotgh. hacl. No cho mourdinut upirf a mar..
#
#    the jrons anlp Coustsarlust. Eto son tupppor of 1Oaf ofy Greeisk oag par in forem
#       Amas Pack thisd. De
#       tfip
# ----
# iter 14300, loss: 52.166396
# ----
#  e cpichire, buce stace thoosen dirkry foc. The and Potjnisw 1eng
#    Galry mowelj wich Morbetpanly buamc
#  Pertanellatl mon wouljert of of
# e thing yoy thy Prakncinnenetr( Proyo u.ith. Fack in Gustrowent
# ----
# iter 14400, loss: 53.049944
# ----
#  g thatp muss
#    fe co to molpperdmon beat to in therent  bey youseist of oreuile theserre fanr ay in “fGoat mo owwanmping Poweutiput dostee
#   pek Gucare
# , Er, anew Bery oa
#   mo who Proick of poayEaila
# ----
# iter 14500, loss: 54.043459
# ----
#  sscicrengoime undinged and.
#
#
#  afPnF-certadk
#     tooclino, anlbon pefgpand the
#  Las
#     Pnapltcisy in.
#
#  7cej
#     Forkenvergart to stamist the
#   “Peat. Geuvitedinatl nor, the wroucoftesplat oEctes oft
# ----
# iter 14600, loss: 54.580701
# ----
#  E TO To
# O
# LO DT TI yRI
#
# Eo
# HoO
#  iOrTNNNFE NO
#
#  I NE TOOd
#  NNT TO
#  To TT NOTN.
#
# 1TTIs
# E 1NI LUERD HO 1O To tIt NOST TpU HO DO ID
#  To ITaLqut TCO I Ip /I UME
#  ODD SR WO
#
#  O IR IT ITo Np
#
#  ETTI STN TriS
# ----
# iter 14700, loss: 56.344270
# ----
#  eng theor wa-ntebb)s Dreu(ith, Retm)s
#   2ad ig 3Fing fuspe fieg pe trowtafan, inr (uspe) pre preasilin op yFerem 3tout besppat I serg 33Ptowpalepont triyilint thiV 10tkuzonL) Heyavereitald of cote. Sh
# ----
# iter 14800, loss: 56.908986
# ----
#  nuse crat But facd   Nomunm gu k2ald and . Wl, avuwlstllerdmancucuts Lapvicuts. SiredHerl mollatuqwa)d wuve whit ingser on Padall and a chers abk cnatering tone aleto andncaidcopmocrexreene wave ll th
# ----
# iter 14900, loss: 57.820888
# ----
#  ar The Me a yrore Che
#  mattinaDCTha	ind Dr what My beattox in
#  R5Com Ane
#  tone 	D/st	es? Co toratrove2stto 0Cary de o7 bem ChanenToaled DrDedso	By “Base1:.
#
# 1Cighy S-er,
#   “L*DLT. 2TCoughatyCef thabny
# ----
# iter 15000, loss: 58.760579
# ----
#  esdort I bit oos on whaselaner and whes pas bad red ussy8I him on Prro inved cfafnort,
#       2ull-ny and stely headect the
#  Lrileet ong pral har and He, beas the mas stewl hea—whRbensssed cve the ingu
# ----
# iter 15100, loss: 58.253953
# ----
#  amint shatpillask cenghr“Th in thes or wroiklustith gorrove to whof mistalmeuniUg nut
#       shats Sin pit that
#       ox , was and kert, ats whatf(eat ar shet the he pove, so. po. Held a on I and me ll
# ----
# iter 15200, loss: 57.439772
# ----
#  sat thatpomeoun a onceds aro and, ter’mert foun tome a he Maugh, ened the, anr1iduloss he, domy E I fert
#       Tout hanict you whron theses. Wron, reidd I to I to      Mmuthingile in of prime loon thi
# ----
# iter 15300, loss: 56.959209
# ----
#   op con, mourt man avlat the coull rendes you amat the
#       tipuos, Nouror mat and it painiy dering proucherf Pre a niton Lobk, war nejeestisns, is gitibre, that
#       in sulinit et tom a dat ammecer
# ----
# iter 15400, loss: 56.636771
# ----
#  ing
#       “Afmer of ol arbum ag.”
#
#       “Yeace wastmy toat olsist trat. ant.C.”
#
#     “wus fre gy Wreally. Sexre. The pray ow yag ally on on
#     frow mymam in foake than ampertur. Mat the yous
#       s
# ----
# iter 15500, loss: 56.039527
# ----
#  oan his mromyidite exstaiocm sitar
#           fry than on
#       ““Is dipec?gouschane. wouidambond buly hal     “I romlesd. Siw patd as withed ary growifaulm hem reachaon tund0 Axt ham extler hhat wlom
# ----
# iter 15600, loss: 55.514892
# ----
#  e tnansics.
#     “a hacnengacaondy pron whaly endvenverl ofted it the habed ain
#       youl your mel enoll yos
#         mesury
#       “Chave fit mat on?orem Ly and werhers the mows, and
#       sied dey nos
# ----
# iter 15700, loss: 54.923385
# ----
#  turt ergur th the to shenanfnaco tbeatcaich your the cat
#         Hor, sheenh afm Shangtwperun
#         hing beld irrhe fore thas as seny wlan te ung Prev mere wror. He mede mild u 8 Whand
#
# ----
# iter 15800, loss: 54.092042
# ----
#  heme shighit sor shadw vof, aut ored n is whet the how of stons lom, sa d1iritcoud toleef Bass_ thins oreron, dae, shitt, a wavs thald the hout of at vis, bere     molest t      Bas his akeldss timed,
# ----
# iter 15900, loss: 53.274460
# ----
#  s, whele that ing in wfoly mad, groyibut Prede ass oondise non Mrcind erse, on wuss with. Hyutet in of shitkenve
# baz
#       preoy tfeaknedd a hentichendibuthvive in efOt hlat jomelose—ass, pecm would h
# ----
# iter 16000, loss: 52.419058
# ----
#  tcalk rat prowh ans that, bunile ing thar the inwa. You boult houls, hernely hell him oon, or fome Bughe maen hasr, bomicexl therele silly merk inr them thioch,
#             iched moonrlenigur to exsy,
# ----
# iter 16100, loss: 52.174319
# ----
#  ndvele
#                 Mutcurg, at whillil of cisty Theod, the copsnyag the sed sxorlany a wenderare onged, thoriondencol, ondter at to for mas h ot the ew pagy ner mat chatf the ared ciccer dout
#
# ----
# iter 16200, loss: 51.621008
# ----
#  ipligvein allive ins agtirelinenqa. Anchen exche in foigrourund inteke un tut                            hised
#                                                  paes fout mous maond Here the sulat icro
# ----
# iter 16300, loss: 51.046678
# ----
#  t      conse oreil ant the Hlacece ur Dr das camse dadick dour ancucs mopporatss. our wetdoly wract a
#       wos to HojsOno7n
#         , anat
#             chites
#         playicimput 3faty
#           thath
# ----
# iter 16400, loss: 50.999434
# ----
#   andys. It the,” ster
#       pharen wavessing
#       “Itttors
#       asteremastoll tood thon yous      neer of a doustarpat boml oass wawl hit ce taccable was and the him of of benur. Sem whostk if to sr
# ----
# iter 16500, loss: 50.703254
# ----
#  ler um ther srung to thaon, ar.
#       “peglt than?”
#
#       plor.”
#
#       once hise. She and on theure ofep veare
#       “We se sime and and you l. ”Ng the and ins, and seat ette, as pry ar
#       “Walre
# ----
# iter 16600, loss: 50.370354
# ----
#   “stind fy“The!d
#       “Ams for. It
#       “I searnt mats cxmeg bed olvuns
#       “You Cureall test of haler to thit ans a mat conkald Siran itcuth and watilecpyourt nor singm se a douth that of hivenmo
# ----
# iter 16700, loss: 49.914699
# ----
#  nly han.”
#
#       “8e
# Chat yeas _on Bast
#       orce datkunis tous he
#  what, “Bs preat thinisker fermuye,” I ming on a and kold, is the und.
#      held the und lad . . of ctayy Sistes it The g the Lond,
# ----
# iter 16800, loss: 49.669153
# ----
#  ar warlly dall thers, his
# , bot aplulimpy ut uened stosourgy coll fougc.
#       hould I 3”
#
#       not a rurperdvoud prowl, bvar otk ank
#       “I hicl that worili3s mato muss,”nglly istiocte Heanest ut
# ----
# iter 16900, loss: 49.520872
# ----
#  msar (ose by whieallen?”
#       canteat eave 6nang oD put tasted Matn thin beever norsowy ierlce I han and ar wwarl unrante on a had dor tradsldin yot rcin the doll iny     deat nor benkinuty thit nle
# ----
# iter 17000, loss: 49.396211
# ----
#      frexy hisn exga. Sh the mecind haencorve a mace
#       “At pout roncer a ly. Leld to rood thocuacr hadtl valy and flourtlincs his freace nocer Heem the frat beach ar chend pat a rodt thar, I us kta
# ----
# iter 17100, loss: 49.320113
# ----
#  beenithere seengut: youllertot oghing on
#    meat if yoarew Werur ats ThavickGrentwingerow. Whyon the whot
#    w oft.”
#
#       “Thimfing. Sherictiing the. Thin entter of u poox rual thioalle the ole.”
#
#
# ----
# iter 17200, loss: 49.120716
# ----
#  ich tare dithourd
#
#  a dive has was
#       idsetione
#   Thy iR
#       ith is ; muney to hished, your un to to cornerssessing cacionerec. The its
#       and was, to diylat ttand sourelestis cfacteet of Bas
# ----
# iter 17300, loss: 49.017306
# ----
#  Masernes, er the hay
#
#       alem t! On of a mar?”
#
#       mat and mepiastiave heed worl glar
#       sap mat se has ro? wirradtureakerel,
#       “I wroteraower
#       ”
#  safissentkaceray dy I iny a t thast
# ----
# iter 17400, loss: 48.932298
# ----
#  yDerevend thet!”
# t the pafepsmourk, anaalced
#     etd?”
#
#       “Whotmened or.
#
#   a beny, purteat marterace Grrimioves’in ader siamy a is, amomarog on?”
#
#       witaowinped way whe.”
#
#       pracentiun pa
# ----
# iter 17500, loss: 49.134674
# ----
#  re that aon the _on and,
#       ouch
#       sighe itstavo hits sess the That senor. She ipmared howticvedtes ussisen is me mase whaspolt cos?”
#  sall wang Wheve daery a besenoar by tho to that yach dom
#
# ----
# iter 17600, loss: 49.201108
# ----
#  tcutes But hadrecals vimy the lloud avinn anl wair a anat ‘e of las with moships a chich ex sistave waid of, bat I con angure rucn in whare—is the whas wis cer wy
#       her in thovamsirubs, Houpy ance
# ----
# iter 17700, loss: 49.141865
# ----
#  e hae you of hame gr.”
# sterertet gonde dout to wat the meinny haneabale o I whit
#       “Weiney wlout be to wigomad, St, bomees Stidew
#       ceblilely and and and is thestar
#       ““You mall.
#     “Wtee
# ----
# iter 17800, loss: 48.896994
# ----
#  .”
#  enk mup coullAney ar mo yepand he ind way prich the heledy co yan avathe
#       “I in. Mow. He tealre. I hen in shew han vid mugh sur is mo
#       padpin butd markid thigen. ang. On
#       “The dane
# ----
# iter 17900, loss: 48.760823
# ----
#  t a bater woocatdod Wa herrinr dromalisk cnat cighart. Hes yoo and Wering Wat of op yos. “Thatpat that mo cowwo a cor, sew thisiind a Henyt le diteams
#       bris it he mabe thalkt and foar waile If wo
# ----
# iter 18000, loss: 48.799787
# ----
#  “Nont dowe larur and abpion. I dount an. Mre Bet vooref. We gof ases. babe thace fleedcat eve hom
#       land dunt ”
#
#       “Hvey fo
#       hate ther ind vut dac?”
#
#       “Welvel a kass the the bhicer a
# ----
# iter 18100, loss: 48.792141
# ----
#    tond is the the mis
#       “You fisskenens, re as rs. I rut this it siin thit oud thin-iigh ly oust.
#  hom it
#       “You ling, ag oi?in ofin, eatester?”
#
#         in
#       “Your mCins, in orewer and Ho
# ----
# iter 18200, loss: 48.723457
# ----
#  e this is af, whose whlonteurit daonchen thiwrowktather Havirt
#       “Your hou up sauld beos that, ald bentico we she res ald
#       Strpos calp wat a wean.”
#
#       “But all a
#       “for acher wur wast
# ----
# iter 18300, loss: 48.702771
# ----
#   be thrid Re?”       inmeng—cission’tnat and’w the and as wowkeictenStord. Ne paze weldoren werdor oay blee reet mroref.
#
#       “You weredtingl wak, faskwark intaam daind toasbenid bealeer Starle a, m
# ----
# iter 18400, loss: 48.667548
# ----
#  with mat. do the its Bur it un.
#       I touderpon
#       ive dor of of angiopaclull. fou ny thasnichoulicun ohetsrorallo mat und loMew of oad sviod efenmom was yavingiomell, wave virt. Bus of.”
#   was c
# ----
# iter 18500, loss: 48.559240
# ----
#  e with abdeap!cow sevierein sid invebbool sareapfee tors pamait per.
#
#       ma-id ald a mur wy il me
#       dener, in, thin’s are the wherk in.”
#
#           “    sely wivemie sisimyop be ache had the Ba
# ----
# iter 18600, loss: 48.573464
# ----
#  ndererst and
#       mend, us
#       wure Yos hamc. wimelteid this sere thin he do, welly the ol afy to come hisdiscer moupleserse whit of the
#       mes ime ind is h. Hillcs conhisp-ne, mat momelwiJnere
# ----
# iter 18700, loss: 48.450358
# ----
#  .”
#
#    a. Strulk tharked ip if jer maustowncil buch Bxalleras sevid each exces.
#
#       “If of frst ic
#
#       pos more
#       3ennisserbat mawl
#    The shankion de bat is it cerpacnce sudmar in id retdom
# ----
# iter 18800, loss: 48.407537
# ----
#
#
#       facs ang torttom’n in whot eseed fot satd w seeg and aller I So mole prouch Sinccill hat hand ageres ot of a any sile nont andalgbaned,” thane ofcon whowmect Stoutced. “Wain
#       “Chatd ing o
# ----
# iter 18900, loss: 48.607216
# ----
#  ouke a lilea wit
#      reed, be sere ate whence hamis fit afouc, un goulur theene manenn the?”
#       ore neleg to I, erod whatd—Bale tooupper,” . “the a c0ule aldue reasem, on
#       Noulcueg, For. The
# ----
# iter 19000, loss: 48.562487
# ----
#  ming, Hnun thist,”
#
#       “I has of cas the. Be sith le vall,. I v Lismeag I cent that kyce, Sheren the to infings wis bpog goller?”
#
#       I
#       “Wiye ild whoss.
#
#       “That, tis
#       “Whios
#
# ----
# iter 19100, loss: 48.538273
# ----
#  younn and cepad firteds the
#
#    “Meney maid pors cutteacibedeen invualeser he cereyabcupked printicare thont yasomeseen the are. Meale,  siblim. Was kbyues tat colerhat.”
#
#       the neon kove the,”
# ----
# iter 19200, loss: 48.503671
# ----
#  nreur it sers. I rich saft. I harlunerse.”
#
#       hang Ghad meet.
#
#       ratdod iir hie ant noth. batcild now it timtiotl pacitaf, forcen sto be ce 6ay iart
#       “Wible ferely cre he to whater wadre.
# ----
# iter 19300, loss: 48.492948
# ----
#  k anin,, whe, ge
#
#
#       he lfast Ont. I disenres. I the mudes
#       geald gray fre Hould
#       par mor, angurondicunet anvesstoul The
#    f is hadd eere beenguqhe des his dore wleare fat *relmer by
# ----
# iter 19400, loss: 48.627832
# ----
#  iso celbing the wat oud thers onmot, wostl, son houndsseserame
#       We on thie fors, thenh the acoult and at reve the wad hero,, yound
#       sims in aecn scoung in st-lee thistedoertire.”
#
#       cout
# ----
# iter 19500, loss: 48.673129
# ----
#  g and ant the sulced rere
#       sis whockeakes. you in us mis, bes his ald the wither ow
#       “Hos tlan wlack
#       is Che.”
#
#       Thatso end. Ther lids do the gith why
#       “But valle ald be uning
# ----
# iter 19600, loss: 48.671522
# ----
#  lencoed ofededa, bettratd saxy villouleurild, sibles a painkid ktust wailiNdy wome
#       moure ad is the tho and hivellech I mac the las, thayaly Proms avor inst a ad man, tof fimad oud gam. Thare bre
# ----
# iter 19700, loss: 48.686663
# ----
#  dtands arlllwrojcilld. Be bead re ut andour whine, th? but
#       “Enstion pes and et tusns. Thigayed hallly
#      sting and orgonthess sling” e
#
#       “Tharl Hall
#       don with the. Cherlar of oote, t
# ----
# iter 19800, loss: 48.540215
# ----
#  nd ungistreftneing sur nesered the su, I hiwores in you dind frram the
# ...
# ----
#  wribal the heet of hatter.”
#
#       “By
#       dene, but this, yound upon
#       noth no have the been expep intliboth hear I kon. A tinz which any porceding be
#
#   the knows basn, broyed ruce a
#
# ----
# iter 833500, loss: 36.924139
# ----
#    day mornome came and long peare more in lifs—twice your. It his getter and the hound, can us any ton all on oul, had site
#       earmees have he shaltly scateravens,” said thing a liked hid suthen ti
# ----
# iter 833600, loss: 36.874113
# ----
#  ways waswer at I we have light Sir Hencyy as aldetany, and the one boot, should must amazely seess oblustion yoa betaut, in no so Jark you denneds proved of he said.
#
# Threting sury in the meation, by
#
# ----
# iter 833700, loss: 36.677240
# ----
#  nome it evidenbe maken” had seesn things thas for Holmes I say a seven 1,” sare wis moobled, and my beca!s.4. LILLLL.”
#
#       “He haket at made as sat to ton has
#       the quise to out vidiow, bunce i
# ----
# iter 833800, loss: 36.589277
# ----
#   desseswim.”
#
#       “That medislry alilly to more downeal, the trae. They in the rand, cloodseath, sherped it
#       on thar her my passiond teed?”
#
#       “It accmpceware.”
#
#       Mere over for in bly,
# ----
# iter 833900, loss: 36.755711
# ----
#  e, would, pestabe trably Barrymore in my yeen a manairster in Barrymold that I shar stankien with completan,” na. The
#       shapletued man, he.
#
#       “Not of heame own who hy
#
#       Charls was in if
# ----
# iter 834000, loss: 36.655967
# ----
#  he sexy the send more acrow was
#       that introw prinal
#       so
#       strad hoalucuwn of he were a confiens Bresa; and he know that changelitf which this and a pungely ued MrTable it we as situlit w
# ----
# iter 834100, loss: 36.769332
# ----
#  ir One the suid Holmesw, thell with trane-last. A thetee; but the fow pustaf alliculy liniss—cantral had prach wife awaret that some was once from its was it of the by our see’s winestes the not of
#
# ----
# iter 834200, loss: 36.854863
# ----
#  f should have oytore over that the
#   he was ond had bussaneal whingen off waited sone whice the prester I whith this an inaving Yeges. Stating
#       I was has agisembarip
#       is in up hird which he
# ----
# iter 834300, loss: 36.980329
# ----
#   cominct.”
#
#       “No
#
#       He deet thealyoudsther wifes. Wur.”
#
#       “fithed that I dool a conveallly both the sady a path I will the fast
#       disst, then it is and can. He noth realite wines his
# ----
# iter 834400, loss: 37.062535
# ----
#     fox dake mins of us, efrient as upor and of which,
#       from who list. From Morcely dear?”
#
#       “Yes wense silench dofd aftered you use it his wonloud
#       here. Bup
#       fog emes House will a
# ----
# iter 834500, loss: 37.290072
# ----
#   in the poared hear and no rust to go a able to
#       unamested done nevor left and very the routted more ovide it Barrymord dightsy
#       that and har dut ue his perember agefenber
#       instenwed us
# ----
# iter 834600, loss: 37.368691
# ----
#  n umour hune which
# sourd and. Her
#      moog of malligite, Watered one seeding his pugs houll.
#
#       Mere is a lootwalle timan clion untringlich his in, barden ichly hell there was heret of of are
#
# ----
# iter 834700, loss: 37.477867
# ----
#   Stactone brought her turned The day. The befur—    “I said not not and swius
#       agoar of begot aspo. Nest it. Af the head hem.”
#
#       “the nevers for
#       him
#       awame and wlysed!” half anroo
# ----
# iter 834800, loss: 37.402506
# ----
#  he warrnecter from store that for culpor ther hall his hearl he
#       bromed hask at this was its to
#       he dow
#       what
#       her of sandle
#       let it did his hurhle you all for down pangeg mav
# ----
# iter 834900, loss: 37.677171
# ----
#  jugelusling. I cannott in sich all id a cuter foot but him the hand with he. “Hos feer in the Mr.
#       Houshing
#       the full us mele.”
#
#       “What but un telenit you him tataned was appeetent agai
# ----
# iter 835000, loss: 37.773815
# ----
#  me one; “Mr-Tht
#       doin
#       sills rounded the of mad not
#       vacked came him, and so gonercuon, and the flazion and a rind-thank-noth.
#
#       “Penge of the consked guther ever of loodes my thir
# ----
# iter 835100, loss: 37.885434
# ----
#   sofed of the heard of the londulus, xhrour. The come, and He maneul mance,
#       nome should muss sited had the whole it pastenched no_ thret, out out that the
#       sustethse-gealdiencting that this
# ----
# iter 835200, loss: 38.112587
# ----
#  hsed fands_ battle he beun in the
#       loubatal about a on the down, sir is by inflasel. Of us. He hasd so Hennent should have intilvats, as us als rekeride could the with, and mus
#       hear did
#
# ----
# iter 835300, loss: 38.030945
# ----
#  ckson off muthle renatows with you a hun called the strie, and datts oft is dinted allessedbvid bus interession!
#       Strendle my pree and of the whill nar Chay sto as mud momure mind. A. A mutho pla
# ----
# iter 835400, loss: 37.996621
# ----
#  own wooks was not acounted is frough you which and ald sind the morsirin the the such been on the house, shem of no great from Stlenidenct of the you seal this
#       dight goge ouc Prest, him taken
#
# ----
# iter 835500, loss: 37.765795
# ----
#    and would friented he was certains works. A. I say for the satitatess here is for our bomestion his dackdating leady spoleations the misceee had roiniowit friagd,
#       die Henry, dayesing with wils
# ----
# iter 835600, loss: 37.825975
# ----
#     pos an is down
#       hip
#       seet to lettersastoy Sir Henry in we have if the revescilmations of the windowil fell.”
#
#       Ohe. I dactentions wainoned hopes
#       poust of his Hit the emprich he
# ----
# iter 835700, loss: 37.729175
# ----
#  sufund there
#
#
#       I wilrealating anit thought! It one that
#       do phaor me mear conlon of staples a you, which Stail, MrNS clancided of to some it for Staplet. This, the moon
#       that to d
# ----
# iter 835800, loss: 37.581595
# ----
#  rich and in which Holmes bethe. Ly, intent intell else enise. But him tilachesence monen to Mested bearlhant was So have mont himition ever outs heably in, the soud hould old veetacurdoy, yountames, w
# ----
# iter 835900, loss: 37.532624
# ----
#  Never ip reasigitn it, and sicany, as      gome Sir Henry; through than free that teen once past that should sevens, other in the feminotty to not any letfinbis armorching my and a aud. He had have se
# ----
# iter 836000, loss: 37.735358
# ----
#  ck perpaskervilenthen over.
#
#       Berestrivistly sorceers,
#       yeiemfply. SE, untummem
#       per.
#       what cromos, dor, if math husiting—greer,
#     T Sir Charles outs bait withight of the of
#
# ----
# iter 836100, loss: 38.836678
# ----
#  Goted his puip toug of lay is givinds, so to creat diffimpt candes’s lefelaiding overormorer every
#       Hilfionstice—ligity Turch way ounct cop is am yegreat wis fcom compnable miret the corcecther o
# ----
# iter 836200, loss: 38.930456
# ----
#  red an Project.Gound whole into the Stap:
#       the cupptia compouncted, I cul it over the folmeaves monnered, thy afterirists. Wy
#     Trot’s titceam with, Mrs.
#
# 1.F.
#
# 1
# Coumbe wad
#       woumsormion d
# ----
# iter 836300, loss: 39.113275
# ----
#  oul abwer
#      purprence inty before coming which cortinken herefG
#     calt and and diong oocts day rerurmat weir thimms
#      near any round l rouvon expelicurer, to licomang bant ed, Enyotllation is
# ----
# iter 836400, loss: 39.338806
# ----
#  tentectine the gasted everpert De delt awake of the efolly the demond ask agpires undire my fol ysall work
#      Amameisa, no  TY I gut enopy spep burion the sade Dr. TUENICT A Hiskering putain an may
# ----
# iter 836500, loss: 40.262098
# ----
#  -Guten.”
#
#     moop firse
#      Ng the
# Plimishact much is town intreparted to comely my trause fust are of (wow the Plaipaction. The cread, my divion it ingescurt Sounder, to filley copyperhon’t lattle
# ----
# iter 836600, loss: 40.678089
# ----
#  own the on the Rebsiculcedor at
#      of Fooldet of the forsted of the marks
#       workn by and of hund
#      cannoth M)Pvenchididicurtianettet. Aciary The
# Portarl
#      benemace that tatestanioc mustabl
# ----
# iter 836700, loss: 41.656993
# ----
#   ITwas
# seatuGns not peags the fogn
#       drolelf corpiented uppenstatich Mrrug throslt
#      -”
#
#       “Enom the for be and soce
#       and begoro of the Project works here pearut pasion of that as wouc
# ----
# iter 836800, loss: 42.448571
# ----
#  ollestionss he sance There
#       heal to faid a wlyer it barured-not-Gutnones that it 434), who inquir, from
#       Unan of us, roung a tilatuble
#       Pry marhing dien one Prring its
#       of un
#
# ----
# iter 836900, loss: 42.173765
# ----
#  laves. There pasilly paskeny.
#
# Be purtlestats at as say withing all, his
#       canion hill injart fruting, or frojt to is
#       sboum. “Baskerva?”
#
#       “There. “Oh hes pard we could.”
#
#       “1742,
# ----
# iter 837000, loss: 41.779319
# ----
#  al othe dain saw a luss. It’s
#       1.”
#
#       “Anrove his acriem upon the
#       as makn side and he have at
# site
#       house is and hattingly this somply man of in oft
# sact-of levences. He Staplopses
# ----
# iter 837100, loss: 41.629184
# ----
#  olmes. “OU No us acquinevininud upon you baost Project of Charlet heres. Think o; way own be I fably 4
# Do
# the conscact, the planicully, shanat our gleare again. My rlacksing at
#       the throaly itson
# ----
# iter 837200, loss: 41.763817
# ----
#   “Untrank the hir second,” sair abous earling that
#       with.
#       “Theic not of Baskervilled.
#
#       “Ohe, as there, and buming is Holmes, and if have mestertaed, his vissh. Twacceed your haken
#
# ----
# iter 837300, loss: 41.509195
# ----
#  was arle some face, which
#       so deware. Pr the agsale, upon the ageferviller inwarler, and
#       dark of off selld corthing no vas cenity by my it on Sin mysene offying of elson, Mr. He have des st
# ----
# iter 837400, loss: 41.123016
# ----
#  ss what undet as poor, ourser-curfing, and I comple that undertakeld is in
#         theer moug
#         Copin gabs, you as was a Comol
#            crofited as falhesont was pestarly entell—expost, the, l
# ----
# iter 837500, loss: 40.865225
# ----
#   aler, after
#
# Came pouvernen good first
#       emplets wavid agomess down is somes,
#
#       Merrom dirfall he warrsonous, down bary this frons somethmath
#       Cecoltited liner or his repeny, has knough
# ----
# iter 837600, loss: 40.479936
# ----
#  o convefted vearch
#             . But
#       his manlpf.     Sir bet drin, sey in the oven from lapee from no then
#             as (h
#         I came about I have have sersy Holmes ence.
#
#       “Versure i
# ----
# iter 837700, loss: 40.037900
# ----
#                    pearsionds the Sir gut hight
#                   discry wish but atpoy it had his was of therg
# her I
#             stressimpret to your which pleetible eyes. It tfine, his mochanced bark
# ----
# iter 837800, loss: 39.449157
# ----
#   of the rece. It is man on
#       tord
#         I hear mark gelect disshing, they of hut pelled side man at mulaigifsed with togetible in known caidy it in sits.”
#
#         hearden as was chaor hall
#
# ----
# iter 837900, loss: 39.368594
# ----
#        consoted me oblazest, sidy dearsalune.
#
#         deen and the more
#             moor you know intrianly somesed of Baskervmeland to ale agate ton, hound bich phongen take your buch could fo
# ----
# iter 838000, loss: 38.997482
# ----
#  s, has elstimpter to padery
#             fored with?
#       Charsed cuts a Baskervalbes know shight be manger Baskerville’s his noightaning
#             fand’s bleart areting of the insent croce upon the
# ----
# iter 838100, loss: 38.542786
# ----
#   as mething anion Enampaveit it woupsceic a concested and one, inclic
#       Barrymore good mad he’n
#       cursest and
#       the provide been, over Holmes. Mire the harresplystaith chick the
#       cuge
# ----
# iter 838200, loss: 38.438476
# ----
#  ave his
#       staple prother
#       the
#       of Sir Charles, and his rats that he
#       upan alon any me
#           “I lonvakders dow keass than upon that and for him. “Very yound fronk here, Mortimed
# ----
# iter 838300, loss: 38.262082
# ----
#   and beattleraly, so pastal of the but and stalles, Mr. Charlt its enœanis to Corad. Goud thedestabloward that
#       dight the constion so to no lomalion whispex us away
#       his of the.”
#
#       “Pen
# ----
# iter 838400, loss: 38.034360
# ----
#  hower hound and has swible full sack seed doars  the cag no beenglest were there whingergurming fiste belatioim.
#       Berers. You was my confess I howe aprouden, er, prifed from which the sees.”
#
#
# ----
# iter 838500, loss: 37.715703
# ----
#  r he dos, cancred. Ruther distrry?”1
#       the Prommenter.
#
#       “I huse which I to land on for the rist dewianfer she have shomishaving fars, hower drincrive when might a reamus
#       which IMland i
# ----
# iter 838600, loss: 37.531398
# ----
#  minoint in I dof that
#       you alplinging to dippat. Basker
#       heling which he was the fald,
#       sit, mayy
#       knotion. ThisserSo Bastrol and for a light up death diring of he work, a soce it
# ----
# iter 838700, loss: 37.429844
# ----
#  s? Holmes.
#
#       “Once,
#       and that thand. It infange. Four deat-moor-ryents and exaccally willting, and a
#       evpry, borer are. Af my has dicibint a mark a corrurning at mine which bliadn toor
# ----
# iter 838800, loss: 37.334800
# ----
#  ys ioto. The posshs that proag priviss safine mighted up his vee, Hened alder.
#
#       “Yesers-edss bule cutioner. “Your man fring. Mides. He had port at preash I shalle
#       consiady he come.
#
# 1.C.C.
# ----
# iter 838900, loss: 37.502310
# ----
#  lonite trown, bothing modred to the 8Cones peath has nothering llantly of Coppon Sir
#
# Chaple Morl, an a countrragn in theng Hall rogr immations the pow mask upon
#       dissisured (anto monnition.”
#
#
# ----
# iter 839000, loss: 37.465603
# ----
#  he browed itvose, that I abligur. It, sor Holmes,” er. Mortiant giving think what rece-junding, one to litary Man will any concem the nirmplee? And allanly front of intimberle. Helllay at Chance, the
# ----
# iter 839100, loss: 37.336699
# ----
#  ery the stolut intats we mrout dissairled me morgether alone?”
#
#       “Hould sooring pack be that
# I the charl, so when my, very had precection to you intrille a
#       nrale estaton that ent-rounded de
# ----
# iter 839200, loss: 37.156733
# ----
#
#       Wut doarrevink come, mousurder.”
#
#       Holmes, Holmes that, it of these all mostware
#       ‘Gctayigipararer?”
#
#       “Dr. Mortice. “He found mithite. Watson
#       pors that sure
#
#
#       I toig
# ----
# iter 839300, loss: 37.318395
# ----
#   Dr. Morrill
#       and evidence yound. Lourd
#       goadl that takn at give-mook as I took his were expect face?”
#
#       “Yes have say sure there
#
#       “Welown of there’s make eys mears a trace baroun
# ----
# iter 839400, loss: 37.418409
# ----
#  iot my yesterfort. The oup scance and in
#       prosed, you UnDunged
#       rountare, and in the shom,” said EXHnlaaly efreatinm, with the congrabe there to pelight. Thin are fersa. Sir Charlest unan, t
# ----
# iter 839500, loss: 37.455441
# ----
#  f
#       the reckow so seen this mure tord of minding prien whosely Pr. vid yeco!”
#
#       “Wes morning was in that long Baskervimmer of our squis fly to they, then mely been one.”
#
#       “Werroadous. “
# ----
# iter 839600, loss: 37.247277
# ----
#  p has expresen sand are?”
#
#       “I was friend?”
#
#       “Hos ere
#       of effied a     telag whith to a quesivisded appeary angert.
#       Holmes’ller inquired you had negosis, eaper of leas of the cla
# ----
# iter 839700, loss: 37.037788
# ----
#  ime. The come ables becade sometachinct ence
#       equing free face which brodame
#       seen eeds the man show a seet the quica. That that’s the Northing to and teld anvis that man, of reporse surtang
# ----
# iter 839800, loss: 37.141374
# ----
#  oment.
#
#       I has ness? What of and do are one he his known, he as the we lize becegesons this dodes was dentionss white!” Hatery unto incely.”
#
#       “What and
#       trin
#       and the dead, I beco
# ----
# iter 839900, loss: 37.122458
# ----
#   which inshant, disht-else of the
#       ther.
#
#       “No, dax,” said hade and
#       queow.
#
#       “No, novil, Dr.”
#
#       “It atpen very have not the halk alley untlesso that youn our nokent my stung,
# ----
# iter 840000, loss: 37.123654
